# %% [markdown]
# <a href="https://colab.research.google.com/github/brrikcy/machine-learning/blob/main/ML_EXP_13_BAGGING_Obesity_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv('/content/drive/MyDrive/DATASETS/obesity_data.csv')
data
# Out:
#      Age  Gender      Height     Weight        BMI  PhysicalActivityLevel  \
# 0     56    Male  173.575262  71.982051  23.891783                      4
# 1     69    Male  164.127306  89.959256  33.395209                      2
# 2     46  Female  168.072202  72.930629  25.817737                      4
# 3     32    Male  168.459633  84.886912  29.912247                      3
# 4     60    Male  183.568568  69.038945  20.487903                      3
# ..   ...     ...         ...        ...        ...                    ...
# 995   18    Male  155.588674  64.103182  26.480345                      4
# 996   35  Female  165.076490  97.639771  35.830783                      1
# 997   49  Female  156.570956  78.804284  32.146036                      1
# 998   64    Male  164.192222  57.978115  21.505965                      4
# 999   66  Female  178.537130  74.962164  23.517168                      1
#
#     ObesityCategory
# 0     Normal weight
# 1             Obese
# ...

# %%
data.dropna(inplace=True)
data.drop_duplicates(inplace=True)

# %%
encoder=LabelEncoder()
data['Gender']=encoder.fit_transform(data['Gender'])
data['ObesityCategory']=encoder.fit_transform(data['ObesityCategory'])

# %%
x=data.drop(columns=['ObesityCategory'])
y=data['ObesityCategory']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
tree=DecisionTreeClassifier(random_state=42)
bagging=BaggingClassifier(base_estimator=tree,n_estimators=30,random_state=42)

# %%
bagging.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=42),
#                   n_estimators=30, random_state=42)

# %%
prediction=bagging.predict(x_test)
accuracy=accuracy_score(y_test,prediction)
print(f"Accuracy is {int((accuracy)*100)}%")
# Out:
# Accuracy is 100%
